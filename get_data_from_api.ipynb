# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#         id                     title  \
# 0      278  The Shawshank Redemption
# 1      238             The Godfather
# 2  1184918            The Wild Robot
# 3      240     The Godfather Part II
# 4      424          Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     206.167
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     208.640
# 2  After a shipwreck, an intelligent robot called...   2024-09-12    5113.594
# 3  In the continuing saga of the Corleone crime f...   1974-12-20     113.959
# 4  The true story of how businessman Oskar Schind...   1993-12-15      73.449
#
#    vote_average  vote_count
# 0         8.707       26969
# 1         8.700       20480
# 2         8.635         728
# 3         8.600       12351
# 4         8.565       15762

# %%
fd=pd.DataFrame()

# %%
for i in range(1, 429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]

    # Concatenate explicitly with fd, no overwriting issue
    fd = pd.concat([fd, temp], ignore_index=True)

# %% [markdown]
# ignore index is used to automatically assign index afer eack append function

# %%
fd.shape
# Out:
#            id                     title  \
# 0         278  The Shawshank Redemption
# 1         238             The Godfather
# 2     1184918            The Wild Robot
# 3         240     The Godfather Part II
# 4         424          Schindler's List
# ...       ...                       ...
# 8555     8920                  Garfield
# 8556   718840      A Nice Girl Like You
# 8557   304372           The Perfect Guy
# 8558     3513               Legionnaire
# 8559   628917        An American Pickle
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     After a shipwreck, an intelligent robot called...   2024-09-12
# 3     In the continuing saga of the Corleone crime f...   1974-12-20
# 4     The true story of how businessman Oskar Schind...   1993-12-15
# ...                                                 ...          ...
# 8555  Garfield, the fat, lazy, lasagna lover, has ev...   2004-06-10
# 8556  Lucy Neal is thrown for a loop when she is acc...   2020-07-18
# 8557  With a fulfilling career and a loving relation...   2015-09-11
# 8558  Alain Lefevre is a boxer paid by a Marseille m...   1998-12-03
# 8559  An immigrant worker at a pickle factory is acc...   2020-07-26
#
#       popularity  vote_average  vote_count
# 0        206.167         8.707       26969
# 1        208.640         8.700       20480
# 2       5113.594         8.635         728
# 3        113.959         8.600       12351
# 4         73.449         8.565       15762
# ...          ...           ...         ...
# 8555      56.041         5.718        3961
# 8556      20.859         5.700         332
# 8557      12.524         5.700         317
# 8558      15.975         5.715         533
# 8559      20.775         5.700         484
#
# [8560 rows x 7 columns]

# %%
fd.to_csv('movies.csv')
